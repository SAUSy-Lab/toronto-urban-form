# %% [markdown]
# ## Downloading OSM Network Data

# %% [markdown]
# Using osmnx and geopandas

# %% [markdown]
# 1 - get a boundary to load the OSM
# 2 - download the graph
# 3 - extract nodes and get counts per node
# 4 - extract edges
# 5 - import into postgres

# %%
import geopandas as gpd
import pandas as pd
import osmnx as ox

#north, south, east, west = 44.987, 42.528, -77.635, -81.144
north, south, east, west = 43.66695, 43.65178, -79.34404, -79.40960

# types of OSM filters
filter_drive = ('["area"!~"yes"]'
            '["highway"!~"motor|trunk|foot|proposed|construction|abandoned|platform|raceway|foot|cycleway"]'
            '["service"!~"driveway|emergency_access|parking_aisle|drive-through"]'
            '["access"!~"private"]')
filter_walk = ('["area"!~"yes"]'
            '["highway"!~"motor|trunk|proposed|construction|abandoned|platform|raceway"]'
            '["foot"!~"no"]'
            '["footway"!~"sidewalk"]'
            '["service"!~"private|parking_aisle"]'
            '["access"!~"private"]')

# downloading and projecting and simplyfing the graph
G = ox.graph_from_bbox(north, south, east, west, custom_filter=filter_drive)
G = ox.project_graph(G)

# %%
ox.save_graphml(G, filename='network_road.graphml')
G = ox.load_graphml('network_road.graphml')

# %%
# grabbing all the nodes and put into a geodataframe
nodes_all = ox.graph_to_gdfs(G, edges=False)
nodes_all = nodes_all.to_crs(epsg=32617)

# count the number of edges per node and join to the nodes geodataframe
streets_per_node = ox.count_streets_per_node(G)
streets_per_node = pd.DataFrame.from_dict(data=streets_per_node,orient='index')
streets_per_node.columns = ["streets_n"]
nodes_all = nodes_all.join(streets_per_node)

# export nodes to a shp
nodes_all.to_file(driver = 'ESRI Shapefile', filename= "network_data/network_roads_nodes.shp")



# this could have been piped directly to a postgres database, but it was downloaded/processed 
# on a different server so it was easier to save as files and then import into a database

# generate edges, and put into a shp

# %%
edges_all = ox.graph_to_gdfs(G, nodes=False)
del edges_all["oneway"],edges_all["bridge"],edges_all["access"],edges_all["highway"]
del edges_all["junction"],edges_all["key"],edges_all["maxspeed"],edges_all["name"]
del edges_all["osmid"],edges_all["service"],edges_all["tunnel"],edges_all["width"],edges_all["lanes"]
edges_all.head(50)
#edges_all.to_file(driver = 'ESRI Shapefile', filename= "network_data/network_roads_edges.shp")
# Out:
#                                              geometry lanes   length  \
# 0   LINESTRING (630256.8407901146 4836128.77792297...     1   16.797
# 1   LINESTRING (630256.8407901146 4836128.77792297...   NaN   14.423
# 2   LINESTRING (630256.8407901146 4836128.77792297...   NaN   24.630
# 3   LINESTRING (630283.2241259 4836047.129234851, ...     1   22.599
# 4   LINESTRING (630283.2241259 4836047.129234851, ...   NaN    7.623
# 5   LINESTRING (629601.9994759518 4836040.97205556...     1   71.437
# 6   LINESTRING (629601.9994759518 4836040.97205556...     3   67.405
# 7   LINESTRING (629547.535299067 4836072.537384743...     6    4.583
# 8   LINESTRING (629547.535299067 4836072.537384743...     3   58.628
# 9   LINESTRING (629535.5912446604 4836017.10906789...     3  103.222
# 10  LINESTRING (630013.7306381559 4835929.00227818...     4    5.024
# 11  LINESTRING (630013.7306381559 4835929.00227818...     4    2.697
# 12  LINESTRING (630013.7306381559 4835929.00227818...     2  192.341
# 13  LINESTRING (629714.9696435136 4835443.38329597...     1   68.116
# 14  LINESTRING (629714.9696435136 4835443.38329597...     4   45.603
# 15  LINESTRING (629775.4899119934 4835460.4339732,...     4  119.832
# 16  LINESTRING (629829.9654072768 4835870.78019944...     2  192.341
# 17  LINESTRING (629821.9598444273 4835568.45207231...     2  105.850
# 18  LINESTRING (629821.9598444273 4835568.45207231...   NaN   50.482
# 19  LINESTRING (629821.9598444273 4835568.45207231...     4  211.744
# 20  LINESTRING (629520.2628204034 4834487.35349764...   NaN   56.265
# 21  LINESTRING (632526.656921041 4835600.444740657...     4  115.596
# 22  LINESTRING (632526.656921041 4835600.444740657...     4  200.276
# 23  LINESTRING (632526.656921041 4835600.444740657...     2   84.158
# 24  LINESTRING (629851.5984450099 4835096.1417033,...     2   23.227
# 25  LINESTRING (629851.5984450099 4835096.1417033,...     4  142.491
# 26  LINESTRING (632015.3727726375 4835349.64491599...     2   67.105
# 27  LINESTRING (632015.3727726375 4835349.64491599...     2   78.402
# 28  LINESTRING (629770.7926495422 4835407.76792488...     1   48.225
# 29  LINESTRING (629770.7926495422 4835407.76792488...     4   54.086
# 30  LINESTRING (629873.8934881731 4835102.84077569...     2   23.227
# 31  LINESTRING (629873.8934881731 4835102.84077569...     4   79.229
# 32  LINESTRING (629873.8934881731 4835102.84077569...     2   36.866
# 33  LINESTRING (628737.5548554062 4835376.50560876...   NaN   20.775
# 34  LINESTRING (629214.3257108475 4835641.91595446...   NaN   33.308
# 35  LINESTRING (629214.3257108475 4835641.91595446...   NaN   21.500
# 36  LINESTRING (629214.3257108475 4835641.91595446...   NaN   37.187
# 37  LINESTRING (629214.3257108475 4835641.91595446...   NaN   39.716
# 38  LINESTRING (628829.9899194363 4834972.00953468...     2   34.395
# 39  LINESTRING (628862.9837157017 4834981.99989661...     2   34.395
# 40  LINESTRING (628862.9837157017 4834981.99989661...     2   45.306
# 41  LINESTRING (628862.9837157017 4834981.99989661...   NaN  102.420
# 42  LINESTRING (630493.9949337133 4836142.83361128...     4   16.518
# 43  LINESTRING (630535.7007020134 4836016.38695018...     3   37.447
# 44  LINESTRING (630535.7007020134 4836016.38695018...     2  220.632
# 45  LINESTRING (630535.7007020134 4836016.38695018...     4   47.302
# 46  LINESTRING (630535.7007020134 4836016.38695018...     4  121.937
# 47  LINESTRING (630745.4733127826 4836086.30330196...     2  151.315
# 48  LINESTRING (630745.4733127826 4836086.30330196...     2  220.632
# 49  LINESTRING (630745.4733127826 4836086.30330196...     5  127.470
#
#              u           v
# 0    701378569   294528879
# 1    701378569  1157211264
# 2    701378569  2259572326
# 3    701378582    95378357
# 4    701378582  2259572314
# 5     20979740    20979743
# 6     20979740    20979742
# 7     20979742   304890341
# 8     20979742    20979743
# 9     20979743  3789187401
# 10   663044129  2143223207
# 11   663044129    49625951
# 12   663044129   663044138
# 13    20979752    20979753
# 14    20979752  1721865354
# 15    20979753    20979755
# 16   663044138   663044129
# 17    20979755    24959513
# 18    20979755    60052065
# 19    20979755  3340615393
# 20   221847595    29604995
# 21  2056859693   292781222
# 22  2056859693    27558325
# 23  2056859693   663394128
# 24    20979760    20979761
# 25    20979760    29604863
# 26  2520301617  2627432819
# 27  2520301617    27559806
# 28    20979762  1721865354
# 29    20979762    20979753
# 30    20979761    20979760
# 31    20979761    42606787
# 32    20979761  2689724249
# 33   145465408   145467101
# 34   130170945    55808527
# 35   130170945   389677905
# 36   130170945   127284680
# 37   130170945   127284677
# 38   835055688   835055690
# 39   835055690   835055688
# 40   835055690    82759642
# 41   835055690    82759633
# 42   338825292    34494566
# 43    25628751   835054147
# 44    25628751    25628755
# 45    25628751   835054117
# 46    25628751    34494654
# 47    25628755    25813937
# 48    25628755    25628751
# 49    25628755    32755998

# %%
#ox.save_graphml(G, filename='network_road.graphml')
#G = ox.load_graphml('network_road.graphml')
