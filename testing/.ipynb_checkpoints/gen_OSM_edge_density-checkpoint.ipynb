# %% [markdown]
# ## Edge Density

# %% [markdown]
# Measures of edge density for hex grid

# %%
# %matplotlib inline
import geopandas as gpd
import pandas as pd
import osmnx as ox
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load in the hex grid (was created in QGIS)

# %%
dfhex = gpd.read_file("../input_data/hex_grid/hex_grid_200m_test_subset.shp").to_crs(epsg=32617)
dfhex = dfhex.set_index('id')

# %%
# get boundary for the OSM
boundary = dfhex.geometry.to_crs(epsg = 4326).unary_union

# %% [markdown]
# Selecting and downloading the OSM network graph using custom filters for selecting ways

# %%
filter_drive = ('["area"!~"yes"]'
            '["highway"!~"motor|trunk|foot|proposed|construction|abandoned|platform|raceway|foot|cycleway"]'
            '["service"!~"driveway|emergency_access|parking_aisle|drive-through"]'
            '["access"!~"private"]')
filter_walk = ('["area"!~"yes"]'
            '["highway"!~"motor|trunk|proposed|construction|abandoned|platform|raceway"]'
            '["foot"!~"no"]'
            '["footway"!~"sidewalk"]'
            '["service"!~"private|parking_aisle"]'
            '["access"!~"private"]')
G = ox.graph_from_polygon(boundary, custom_filter=filter_drive)
G = ox.project_graph(G)
# fig, ax = ox.plot_graph(G, node_size=30, node_color='#66cc66') # for plotting :)

# %%
edges_all = ox.graph_to_gdfs(G_walk, nodes=False)
edges_all.head()
# Out:
#   access bridge                                           geometry  \
# 0    NaN    NaN  LINESTRING (631279.2088800078 4834185.18948211...
# 1    NaN    NaN  LINESTRING (631279.2088800078 4834185.18948211...
# 2    NaN    NaN  LINESTRING (631279.2088800078 4834185.18948211...
# 3    NaN    NaN  LINESTRING (632147.5095001051 4834034.68541808...
# 4    NaN    NaN  LINESTRING (632128.5376280777 4833749.61181760...
#
#          highway  key lanes   length maxspeed               name  oneway  \
# 0      secondary    0     3   35.547      NaN  Front Street East    True
# 1  living_street    0     1   11.498      NaN      Market Street   False
# 2  living_street    0     1  123.937      NaN      Market Street    True
# 3        footway    0   NaN   16.431      NaN                NaN   False
# 4    residential    0   NaN  304.872      NaN   Merchant's Wharf   False
#
#                     osmid service tunnel           u           v
# 0               162585239     NaN    NaN   280375304  3308179758
# 1               446989382     NaN    NaN   280375304   249977880
# 2                23143717     NaN    NaN   280375304   249975742
# 3               562037318     NaN    NaN  5418655754  5418664342
# 4  [403479251, 545430590]     NaN    NaN  5271552022  2311428239

# %%
edges_all.plot()
